# %%
import pandas as pd

# %%
from google.colab import files
# Carga el archivo kaggle.json
files.upload()

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
! python -m pip install -qq kaggle
# !kaggle competitions download -c udea-ai4eng-20241
# !unzip udea-ai4eng-20241.zip
# Out:
#      <input type="file" id="files-8fad6fca-6132-4860-90cb-8ef4c3c3203b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fad6fca-6132-4860-90cb-8ef4c3c3203b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/train.csv', encoding= 'utf-8')
df.head()
# Out:
#        ID  PERIODO         ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 0  904256    20212                  ENFERMERIA                 BOGOTÁ
# 1  645256    20212                     DERECHO              ATLANTICO
# 2  308367    20203       MERCADEO Y PUBLICIDAD                 BOGOTÁ
# 3  470353    20195  ADMINISTRACION DE EMPRESAS              SANTANDER
# 4  989032    20212                  PSICOLOGIA              ANTIOQUIA
#
#              ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                       0
# 2  Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                       0
# 4  Entre 2.5 millones y menos de 4 millones     Entre 21 y 30 horas
#
#   FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET                 FAMI_EDUCACIONPADRE  \
# ...

# %%
df.columns

#Aqui se pueden observar las columnas del dataframe
# Out:
# Index(['ID', 'PERIODO', 'ESTU_PRGM_ACADEMICO', 'ESTU_PRGM_DEPARTAMENTO',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_HORASSEMANATRABAJA',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONPADRE',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEAUTOMOVIL', 'ESTU_PRIVADO_LIBERTAD',
#        'ESTU_PAGOMATRICULAPROPIO', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENEINTERNET.1', 'FAMI_EDUCACIONMADRE', 'RENDIMIENTO_GLOBAL'],
#       dtype='object')

# %% [markdown]
# basandonos en el contador de podemos observar la cantidad de datos totales, Como el Id solo es un identificador de orden no nos sirve para nada analizar esos datos estadisticamente, por otra parte la casilla de periodo que se refiere al año seguido del mes donde fue

# %%
df[(df.FAMI_TIENECOMPUTADOR=='Si')&(df.FAMI_TIENEAUTOMOVIL == 'Si')].count()

#Este recuadro podemos observar a traves del contador del ID la cantidad de personas que contaban con automovil y tenian computador en su familia
# Out:
# ID                                230049
# PERIODO                           230049
# ESTU_PRGM_ACADEMICO               230049
# ESTU_PRGM_DEPARTAMENTO            230049
# ESTU_VALORMATRICULAUNIVERSIDAD    227592
# ESTU_HORASSEMANATRABAJA           228884
# FAMI_ESTRATOVIVIENDA              227743
# FAMI_TIENEINTERNET                229847
# FAMI_EDUCACIONPADRE               229478
# FAMI_TIENELAVADORA                229780
# FAMI_TIENEAUTOMOVIL               230049
# ESTU_PRIVADO_LIBERTAD             230049
# ESTU_PAGOMATRICULAPROPIO          227513
# FAMI_TIENECOMPUTADOR              230049
# FAMI_TIENEINTERNET.1              229847
# FAMI_EDUCACIONMADRE               229521
# RENDIMIENTO_GLOBAL                230049
# dtype: int64

# %%
df[df.PERIODO == 20212]
df.info()

#En este recuadro podemos observar la frecuencia de estudiantes que realizaron la prueba en el periodo 2021 2, ver cuanta memoria usa el dataframe y que solo cuenta con dos columnas de enteros mientras que el resto solo son strings
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692500 entries, 0 to 692499
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ID                              692500 non-null  int64
#  1   PERIODO                         692500 non-null  int64
#  2   ESTU_PRGM_ACADEMICO             692500 non-null  object
#  3   ESTU_PRGM_DEPARTAMENTO          692500 non-null  object
#  4   ESTU_VALORMATRICULAUNIVERSIDAD  686213 non-null  object
#  5   ESTU_HORASSEMANATRABAJA         661643 non-null  object
#  6   FAMI_ESTRATOVIVIENDA            660363 non-null  object
#  7   FAMI_TIENEINTERNET              665871 non-null  object
#  8   FAMI_EDUCACIONPADRE             669322 non-null  object
#  9   FAMI_TIENELAVADORA              652727 non-null  object
#  10  FAMI_TIENEAUTOMOVIL             648877 non-null  object
#  11  ESTU_PRIVADO_LIBERTAD           692500 non-null  object
# ...

# %%
df[(df.PERIODO == 20212) & (df.RENDIMIENTO_GLOBAL=='alto')& (df.ESTU_PRGM_DEPARTAMENTO == 'ANTIOQUIA')].describe()

# a traves de esta podemos ver la cantidad de gente que pertenecian a antioquia en el periodo 2021 2 y tuvieron rendimiento global alto
# Out:
#                   ID  PERIODO
# count    5821.000000   5821.0
# mean   492626.794537  20212.0
# std    284378.465239      0.0
# min      2833.000000  20212.0
# 25%    246386.000000  20212.0
# 50%    490864.000000  20212.0
# 75%    738802.000000  20212.0
# max    989246.000000  20212.0

# %%
df[(df.PERIODO == 20212) & (df.ESTU_PRGM_ACADEMICO == 'INGENIERIA INDUSTRIAL')].head()
# Out:
#          ID  PERIODO    ESTU_PRGM_ACADEMICO ESTU_PRGM_DEPARTAMENTO  \
# 8    257869    20212  INGENIERIA INDUSTRIAL              ATLANTICO
# 27   336160    20212  INGENIERIA INDUSTRIAL                 BOGOTÁ
# 73   258671    20212  INGENIERIA INDUSTRIAL                 BOGOTÁ
# 455  637832    20212  INGENIERIA INDUSTRIAL                  VALLE
# 525  607099    20212  INGENIERIA INDUSTRIAL                 BOGOTÁ
#
#                ESTU_VALORMATRICULAUNIVERSIDAD ESTU_HORASSEMANATRABAJA  \
# 8    Entre 5.5 millones y menos de 7 millones       Menos de 10 horas
# 27   Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 73   Entre 2.5 millones y menos de 4 millones         Más de 30 horas
# 455                         Más de 7 millones                       0
# 525    Entre 1 millón y menos de 2.5 millones     Entre 11 y 20 horas
#
#     FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 8              Estrato 1                 Si
# 27             Estrato 3                 Si
# ...

# %%
df[(df.PERIODO == 20212) & (df.ESTU_PRGM_ACADEMICO == 'LICENCIATURA EN EDUCACION PREESCOLAR')&(df.ESTU_PRGM_DEPARTAMENTO=='BOGOTÁ')].tail()
# Out:
#             ID  PERIODO                   ESTU_PRGM_ACADEMICO  \
# 481323  257952    20212  LICENCIATURA EN EDUCACION PREESCOLAR
# 516460   22622    20212  LICENCIATURA EN EDUCACION PREESCOLAR
# 548545  266644    20212  LICENCIATURA EN EDUCACION PREESCOLAR
# 607006  626137    20212  LICENCIATURA EN EDUCACION PREESCOLAR
# 641624  274282    20212  LICENCIATURA EN EDUCACION PREESCOLAR
#
#        ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 481323                 BOGOTÁ    Entre 1 millón y menos de 2.5 millones
# 516460                 BOGOTÁ    Entre 1 millón y menos de 2.5 millones
# 548545                 BOGOTÁ    Entre 1 millón y menos de 2.5 millones
# 607006                 BOGOTÁ  Entre 2.5 millones y menos de 4 millones
# 641624                 BOGOTÁ    Entre 1 millón y menos de 2.5 millones
#
#        ESTU_HORASSEMANATRABAJA FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET  \
# 481323       Menos de 10 horas            Estrato 2                 Si
# ...
